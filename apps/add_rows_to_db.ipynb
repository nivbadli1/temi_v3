# %%
from apps.authentication.models import Users,Patient,Contact,ContactsTime
from apps import db
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from apps.authentication.models import Users,Patient,Contact,ContactsTime
#       2 from apps import db
#
# File ~\PycharmProjects\temi_v3\apps\authentication\models.py:94, in <module>
#      90     def __repr__(self):
#      91         return 'Contact(%r,%r, %r, %r, %r, %r, %r)' % (self.contact_id,self.f_name, self.l_name, self.phone, self.mail,self.priority,self.patient_id)
# ---> 94 class ContactsTime(db.Model):
#      95     __tablename__ = 'contacts_times'
#      97     contact_id = db.Column(db.Integer, db.ForeignKey('contacts.contact_id', ondelete='CASCADE', onupdate='CASCADE'))
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\flask_sqlalchemy\model.py:67, in NameMetaMixin.__init__(cls, name, bases, d)
#      64 if should_set_tablename(cls):
#      65     cls.__tablename__ = camel_to_snake_case(cls.__name__)
# ---> 67 super(NameMetaMixin, cls).__init__(name, bases, d)
#      69 # __table_cls__ has run at this point
#      70 # if no table was created, use the parent table
#      71 if (
#      72     '__tablename__' not in cls.__dict__
#      73     and '__table__' in cls.__dict__
#      74     and cls.__dict__['__table__'] is None
#      75 ):
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\flask_sqlalchemy\model.py:121, in BindMetaMixin.__init__(cls, name, bases, d)
#     115 def __init__(cls, name, bases, d):
#     116     bind_key = (
#     117         d.pop('__bind_key__', None)
#     118         or getattr(cls, '__bind_key__', None)
#     119     )
# --> 121     super(BindMetaMixin, cls).__init__(name, bases, d)
#     123     if bind_key is not None and getattr(cls, '__table__', None) is not None:
#     124         cls.__table__.info['bind_key'] = bind_key
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_api.py:72, in DeclarativeMeta.__init__(cls, classname, bases, dict_, **kw)
#      69         cls._sa_registry = reg
#      71 if not cls.__dict__.get("__abstract__", False):
# ---> 72     _as_declarative(reg, cls, dict_)
#      73 type.__init__(cls, classname, bases, dict_)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_base.py:126, in _as_declarative(registry, cls, dict_)
#     121 def _as_declarative(registry, cls, dict_):
#     122
#     123     # declarative scans the class for attributes.  no table or mapper
#     124     # args passed separately.
# --> 126     return _MapperConfig.setup_mapping(registry, cls, dict_, None, {})
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_base.py:177, in _MapperConfig.setup_mapping(cls, registry, cls_, dict_, table, mapper_kw)
#     174 else:
#     175     cfg_cls = _ClassScanMapperConfig
# --> 177 return cfg_cls(registry, cls_, dict_, table, mapper_kw)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_base.py:326, in _ClassScanMapperConfig.__init__(self, registry, cls_, dict_, table, mapper_kw)
#     322 self._setup_table(table)
#     324 self._setup_inheritance(mapper_kw)
# --> 326 self._early_mapping(mapper_kw)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_base.py:209, in _MapperConfig._early_mapping(self, mapper_kw)
#     208 def _early_mapping(self, mapper_kw):
# --> 209     self.map(mapper_kw)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\decl_base.py:1004, in _ClassScanMapperConfig.map(self, mapper_kw)
#     999 else:
#    1000     mapper_cls = mapper
#    1002 return self.set_cls_attribute(
#    1003     "__mapper__",
# -> 1004     mapper_cls(self.cls, self.local_table, **self.mapper_args),
#    1005 )
#
# File <string>:2, in __init__(self, class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\mapper.py:685, in Mapper.__init__(self, class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#     683 self._configure_properties()
#     684 self._configure_polymorphic_setter()
# --> 685 self._configure_pks()
#     686 self.registry._flag_new_mapper(self)
#     687 self._log("constructed")
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\mapper.py:1370, in Mapper._configure_pks(self)
#    1365 # otherwise, see that we got a full PK for the mapped table
#    1366 elif (
#    1367     self.persist_selectable not in self._pks_by_table
#    1368     or len(self._pks_by_table[self.persist_selectable]) == 0
#    1369 ):
# -> 1370     raise sa_exc.ArgumentError(
#    1371         "Mapper %s could not assemble any primary "
#    1372         "key columns for mapped table '%s'"
#    1373         % (self, self.persist_selectable.description)
#    1374     )
#    1375 elif self.local_table not in self._pks_by_table and isinstance(
#    1376     self.local_table, schema.Table
#    1377 ):
#    1378     util.warn(
#    1379         "Could not assemble any primary "
#    1380         "keys for locally mapped table '%s' - "
#    1381         "no rows will be persisted in this Table."
#    1382         % self.local_table.description
#    1383     )
#
# ArgumentError: Mapper mapped class ContactsTime->contacts_times could not assemble any primary key columns for mapped table 'contacts_times'

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
e = 'mysql+pymysql://naya:NayaPass1!@35.226.141.122/temi_v3'
engine = create_engine(e)

# %%
from sqlalchemy.orm import Session
session = Session(engine)

# %%
# Add patients
# p1 = Patient(patient_id=1,f_name="ניב",l_name="כהן",bed=2,department=1,max_calls=2)
p2 = Patient(patient_id=7,f_name="טל",l_name="שרעבי",bed=22,department=1,max_calls=2)
p3 = Patient(patient_id=3,f_name="ליאור",l_name="כהן",bed=21,department=1,max_calls=2)
p4 = Patient(patient_id=8,f_name="עילי",l_name="כהן",bed=3,department=1,max_calls=2)
p5 = Patient(patient_id=5,f_name="קרן",l_name="לוי",bed=4,department=1,max_calls=2)
p6 = Patient(patient_id=6,f_name="משה",l_name="בדלי",bed=12,department=1,max_calls=2)
# patients=[]
session.add_all([p2,p3,p4,p5,p6])
session.commit()

# %%
# Add contacts
e1 = Contact(2,"ניב","חזן","0417451515","n@gmail.com",1)
e2 = Contact(2,"טל","לוי","0417451515","n@gmail.com","",1)
e3 = Contact(4,"ליפז","מאיר","0417451515","n@gmail.com",1)
e4 = Contact(4,"קרן","בר","0417451515","n@gmail.com","",1)
e5 = Contact(12,"חן","חנן","0417451515","n@gmail.com",1)
e6 = Contact(2,"נטע","גד","0417451515","n@gmail.com",1)

session.add_all([c1,c2,c3,c4,c5,c6])
session.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 3>()
#       1 # Add contacts
#       2 e1 = Contact(2,"ניב","חזן","0417451515","n@gmail.com",1)
# ----> 3 e2 = Contact(2,"טל","לוי","0417451515","n@gmail.com","",1)
#       4 e3 = Contact(4,"ליפז","מאיר","0417451515","n@gmail.com",1)
#       5 e4 = Contact(4,"קרן","בר","0417451515","n@gmail.com","",1)
#
# TypeError: __init__() takes 7 positional arguments but 8 were given

# %%
# Add contacts times
c1 = ContactsTime(2,4,"10:00","14:00")
c2 = ContactsTime(2,2,"10:00","14:00")
c3 = ContactsTime(2,3,"10:00","14:00")
c4 = ContactsTime(4,4,"10:00","14:00")
c5 = ContactsTime(4,2,"10:00","14:00")
c6 = ContactsTime(4,3,"10:00","14:00")
session.add_all([c1,c2,c3,c4,c5,c6])
session.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:1782, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1781     if not evt_handled:
# -> 1782         self.dialect.do_executemany(
#    1783             cursor, statement, parameters, context
#    1784         )
#    1785 elif not parameters and context.no_parameters:
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:173, in Cursor.executemany(self, query, args)
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#     176         q_postfix,
#     177         args,
#     178         self.max_stmt_length,
#     179         self._get_db().encoding,
#     180     )
#     182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:211, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210     sql += v
# --> 211 rows += self.execute(sql + postfix)
#     212 self.rowcount = rows
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '4-10:00:00-14:00:00' for key 'contacts_times.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Input In [4], in <cell line: 9>()
#       7 c6 = ContactsTime(4,3,"10:00","14:00")
#       8 session.add_all([c1,c2,c3,c4,c5,c6])
# ----> 9 session.commit()
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:1431, in Session.commit(self)
#    1428     if not self._autobegin():
#    1429         raise sa_exc.InvalidRequestError("No transaction is begun.")
# -> 1431 self._transaction.commit(_to_root=self.future)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:829, in SessionTransaction.commit(self, _to_root)
#     827 self._assert_active(prepared_ok=True)
#     828 if self._state is not PREPARED:
# --> 829     self._prepare_impl()
#     831 if self._parent is None or self.nested:
#     832     for conn, trans, should_commit, autoclose in set(
#     833         self._connections.values()
#     834     ):
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:808, in SessionTransaction._prepare_impl(self)
#     806     if self.session._is_clean():
#     807         break
# --> 808     self.session.flush()
#     809 else:
#     810     raise exc.FlushError(
#     811         "Over 100 subsequent flushes have occurred within "
#     812         "session.commit() - is an after_flush() hook "
#     813         "creating new objects?"
#     814     )
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:3363, in Session.flush(self, objects)
#    3361 try:
#    3362     self._flushing = True
# -> 3363     self._flush(objects)
#    3364 finally:
#    3365     self._flushing = False
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:3502, in Session._flush(self, objects)
#    3499     transaction.commit()
#    3501 except:
# -> 3502     with util.safe_reraise():
#    3503         transaction.rollback(_capture_exception=True)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:3463, in Session._flush(self, objects)
#    3461 self._warn_on_events = True
#    3462 try:
# -> 3463     flush_context.execute()
#    3464 finally:
#    3465     self._warn_on_events = False
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\unitofwork.py:456, in UOWTransaction.execute(self)
#     454 else:
#     455     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 456         rec.execute(self)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\unitofwork.py:630, in SaveUpdateAll.execute(self, uow)
#     628 @util.preload_module("sqlalchemy.orm.persistence")
#     629 def execute(self, uow):
# --> 630     util.preloaded.orm_persistence.save_obj(
#     631         self.mapper,
#     632         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     633         uow,
#     634     )
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\persistence.py:244, in save_obj(base_mapper, states, uowtransaction, single)
#     232     update = _collect_update_commands(
#     233         uowtransaction, table, states_to_update
#     234     )
#     236     _emit_update_statements(
#     237         base_mapper,
#     238         uowtransaction,
#    (...)
#     241         update,
#     242     )
# --> 244     _emit_insert_statements(
#     245         base_mapper,
#     246         uowtransaction,
#     247         mapper,
#     248         table,
#     249         insert,
#     250     )
#     252 _finalize_insert_update_commands(
#     253     base_mapper,
#     254     uowtransaction,
#    (...)
#     270     ),
#     271 )
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\persistence.py:1096, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping)
#    1093 records = list(records)
#    1094 multiparams = [rec[2] for rec in records]
# -> 1096 c = connection._execute_20(
#    1097     statement, multiparams, execution_options=execution_options
#    1098 )
#    1100 if bookkeeping:
#    1101     for (
#    1102         (
#    1103             state,
#    (...)
#    1112         last_inserted_params,
#    1113     ) in zip(records, c.context.compiled_parameters):
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:1614, in Connection._execute_20(self, statement, parameters, execution_options)
#    1610     util.raise_(
#    1611         exc.ObjectNotExecutableError(statement), replace_context=err
#    1612     )
#    1613 else:
# -> 1614     return meth(self, args_10style, kwargs_10style, execution_options)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\sql\elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:1481, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1469 compiled_cache = execution_options.get(
#    1470     "compiled_cache", self.engine._compiled_cache
#    1471 )
#    1473 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1474     dialect=dialect,
#    1475     compiled_cache=compiled_cache,
#    (...)
#    1479     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1480 )
# -> 1481 ret = self._execute_context(
#    1482     dialect,
#    1483     dialect.execution_ctx_cls._init_compiled,
#    1484     compiled_sql,
#    1485     distilled_params,
#    1486     execution_options,
#    1487     compiled_sql,
#    1488     distilled_params,
#    1489     elem,
#    1490     extracted_params,
#    1491     cache_hit=cache_hit,
#    1492 )
#    1493 if has_events:
#    1494     self.dispatch.after_execute(
#    1495         self,
#    1496         elem,
#    (...)
#    1500         ret,
#    1501     )
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\engine\base.py:1782, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1780                 break
#    1781     if not evt_handled:
# -> 1782         self.dialect.do_executemany(
#    1783             cursor, statement, parameters, context
#    1784         )
#    1785 elif not parameters and context.no_parameters:
#    1786     if self.dialect._has_events:
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#     195         context._rowcount = rowcount
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:173, in Cursor.executemany(self, query, args)
#     171     q_postfix = m.group(3) or ""
#     172     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173     return self._do_execute_many(
#     174         q_prefix,
#     175         q_values,
#     176         q_postfix,
#     177         args,
#     178         self.max_stmt_length,
#     179         self._get_db().encoding,
#     180     )
#     182 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     183 return self.rowcount
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:211, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209         sql += b","
#     210     sql += v
# --> 211 rows += self.execute(sql + postfix)
#     212 self.rowcount = rows
#     213 return rows
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '4-10:00:00-14:00:00' for key 'contacts_times.PRIMARY'")
# [SQL: INSERT INTO contacts_times (contact_id, day, `from`, `to`) VALUES (%(contact_id)s, %(day)s, %(from)s, %(to)s)]
# [parameters: ({'contact_id': 2, 'day': 4, 'from': '10:00', 'to': '14:00'}, {'contact_id': 2, 'day': 2, 'from': '10:00', 'to': '14:00'}, {'contact_id': 2, 'day': 3, 'from': '10:00', 'to': '14:00'}, {'contact_id': 4, 'day': 4, 'from': '10:00', 'to': '14:00'}, {'contact_id': 4, 'day': 2, 'from': '10:00', 'to': '14:00'}, {'contact_id': 4, 'day': 3, 'from': '10:00', 'to': '14:00'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# Add events
c1 = Contact(2,"ניב","חזן","0417451515","n@gmail.com",1)
c2 = Contact(4,"טל","לוי","0417451515","n@gmail.com",1)
c3 = Contact(2,"ליפז","מאיר","0417451515","n@gmail.com",1)
c4 = Contact(4,"קרן","בר","0417451515","n@gmail.com",1)
c5 = Contact(2,"חן","חנן","0417451515","n@gmail.com",1)
c6 = Contact(4,"נטע","גד","0417451515","n@gmail.com",1)

session.add_all([c1,c2,c3,c4,c5,c6])
session.commit()

# %%
c1 = Contact(2,"ניב","חזן","0417451515","n@gmail.com",1)
session.add(c1)
session.commit()

# %%
p5 = Patient(patient_id=15,f_name="קרן",l_name="לוי",bed=4,department=1,max_calls=2)
session.add(p5)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\_collections.py:1008, in ScopedRegistry.__call__(self)
#    1007 try:
# -> 1008     return self.registry[key]
#    1009 except KeyError:
#
# KeyError: <greenlet.greenlet object at 0x000002694FDC17A0 (otid=0x000002694D379380) current active started main>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 p = Patient.query.filter_by(patient_id=patient_id).first_or_404()
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\flask_sqlalchemy\__init__.py:552, in _QueryProperty.__get__(self, obj, type)
#     550     mapper = orm.class_mapper(type)
#     551     if mapper:
# --> 552         return type.query_class(mapper, session=self.sa.session())
#     553 except UnmappedClassError:
#     554     return None
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\scoping.py:47, in ScopedSessionMixin.__call__(self, **kw)
#      45         self.registry.set(sess)
#      46 else:
# ---> 47     sess = self.registry()
#      48 if not self._support_async and sess._is_asyncio:
#      49     warn_deprecated(
#      50         "Using `scoped_session` with asyncio is deprecated and "
#      51         "will raise an error in a future version. "
#      52         "Please use `async_scoped_session` instead.",
#      53         "1.4.23",
#      54     )
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\util\_collections.py:1010, in ScopedRegistry.__call__(self)
#    1008     return self.registry[key]
#    1009 except KeyError:
# -> 1010     return self.registry.setdefault(key, self.createfunc())
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\sqlalchemy\orm\session.py:4195, in sessionmaker.__call__(self, **local_kw)
#    4193     else:
#    4194         local_kw.setdefault(k, v)
# -> 4195 return self.class_(**local_kw)
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\flask_sqlalchemy\__init__.py:174, in SignallingSession.__init__(self, db, autocommit, autoflush, **options)
#     172 def __init__(self, db, autocommit=False, autoflush=True, **options):
#     173     #: The application that this session belongs to.
# --> 174     self.app = app = db.get_app()
#     175     track_modifications = app.config['SQLALCHEMY_TRACK_MODIFICATIONS']
#     176     bind = options.pop('bind', None) or db.engine
#
# File C:\ProgramData\Anaconda3\envs\temi_v3\lib\site-packages\flask_sqlalchemy\__init__.py:1042, in SQLAlchemy.get_app(self, reference_app)
#    1039 if self.app is not None:
#    1040     return self.app
# -> 1042 raise RuntimeError(
#    1043     'No application found. Either work inside a view function or push'
#    1044     ' an application context. See'
#    1045     ' http://flask-sqlalchemy.pocoo.org/contexts/.'
#    1046 )
#
# RuntimeError: No application found. Either work inside a view function or push an application context. See http://flask-sqlalchemy.pocoo.org/contexts/.

# %%
session.query(Contact).all()
# Out:
# [Contact('ניב', 'חזן', '0417451515', 'n@gmail.com', 1, 2),
#  Contact('ניב', 'חזן', '0417451515', 'n@gmail.com', 1, 2),
#  Contact('טל', 'לוי', '0417451515', 'n@gmail.com', 1, 4),
#  Contact('ליפז', 'מאיר', '0417451515', 'n@gmail.com', 1, 2),
#  Contact('קרן', 'בר', '0417451515', 'n@gmail.com', 1, 4),
#  Contact('חן', 'חנן', '0417451515', 'n@gmail.com', 1, 2),
#  Contact('נטע', 'גד', '0417451515', 'n@gmail.com', 1, 4)]

# %%
c6 = session.query(Contact).filter_by(patient_id=2)
session.query(Contact).filter_by(contact_id=2)

# %%
c2 = session.query(Contact).filter_by(contact_id=2).all()
c2 = ContactsTime(2,1,"10:00","14:00")
ContactsTime(2,1,"10:00","14:00")
session.add(c2)
session.commit()

# %%
patient = session.query(Patient).first()
# patient
contacts = patient.contacts
contacts
# Out:
# [Contact('ניב', 'חזן', '0417451515', 'n@gmail.com', 2),
#  Contact('ניב', 'חזן', '0417451515', 'n@gmail.com', 2),
#  Contact('ליפז', 'מאיר', '0417451515', 'n@gmail.com', 2),
#  Contact('חן', 'חנן', '0417451515', 'n@gmail.com', 2)]

# %%
# get patient with id = 2
records = session.query(Patient).filter_by(patient_id=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 records = session.query(Patient).filter_by(patient_id=2).get(patient_id)
#       2 records
#
# NameError: name 'patient_id' is not defined
